# %%
import cudf
import pandas as pd
import re

# %%
df = cudf.read_csv("Bitcoin_tweets.csv")

# %%
df = df.dropna()
df = df.drop(columns=["user_description", "is_retweet"])
df
# Out:
#                                         user_name            user_location  \
# 0                                   DeSota Wilson              Atlanta, GA
# 4        Alex Kirchmaier 🇦🇹🇸🇪 #FactsSuperspreader                   Europa
# 5                             ZerrBenz™ ⚔ ✪ 20732            Bkk, Thailand
# 6                                     Bitcoin-Bot             Florida, USA
# 9                                   DeSota Wilson              Atlanta, GA
# ...                                           ...                      ...
# 4689343                            Crypto Alerted                      USA
# 4689344                                     世界杯下注                   联系方式↑↑
# 4689347                                   世界杯投注平台                   联系方式↑↑
# 4689349                                 TAnotepad     Not financial advice
# 4689350                                  Boba-Feh  South of the North Pole
#
# ...

# %%
def chinese_words(text):
    if pd.isnull(text):
        return False
    return bool(re.search(r'[\u4e00-\u9fff]', text))

pdf = df.to_pandas()

pdf = pdf[
    ~pdf['user_name'].apply(chinese_words) &
    ~pdf['user_location'].apply(chinese_words) &
    ~pdf['text'].apply(chinese_words)
]

df = cudf.DataFrame.from_pandas(pdf)
df = df.reset_index(drop=True)
df
# Out:
#                                         user_name            user_location  \
# 0                                   DeSota Wilson              Atlanta, GA
# 1        Alex Kirchmaier 🇦🇹🇸🇪 #FactsSuperspreader                   Europa
# 2                             ZerrBenz™ ⚔ ✪ 20732            Bkk, Thailand
# 3                                     Bitcoin-Bot             Florida, USA
# 4                                   DeSota Wilson              Atlanta, GA
# ...                                           ...                      ...
# 2214133                                CryptoHulk              Cryptoworld
# 2214134                                Richy Rich                  FinTwit
# 2214135                            Crypto Alerted                      USA
# 2214136                                 TAnotepad     Not financial advice
# 2214137                                  Boba-Feh  South of the North Pole
#
# ...

# %%
df['user_created'] = cudf.to_datetime(df['user_created']).astype(str).str.slice(0, 10)
df['date'] = cudf.to_datetime(df['date']).astype(str).str.slice(0, 10)

df['user_location'] = df['user_location'].str.replace('türkiye', 'turkey')
df['user_location'] = df['user_location'].str.replace('brasil', 'brazil')

# %%
df['user_location'] = df['user_location'].fillna("")
df['user_location'] = df['user_location'].str.lower()
frases_no_geograficas = [
    "not financial advice",
    "nfa",
    "mars",
    "moon",
    "everywhere",
    "internet",
    "cryptoworld",
    "try it for free 👉",
    "whatsapp for info 👉👉👉",
    "0x",
    "alpha? 👇🏼 dyor! ⚠️ amen. 🙏",
    "old town alley",
    "tcg world, north side squid",
    "freedom's landing",
    "hasilpur",       
    "not in the kitchen", "web3", "nova", "europa", "bkk", "wy, ca, id, co, tn",
    "world",
    "market place",
    "south of the north pole",
    "fintwit",
    "the crypto block",
]



for frase in frases_no_geograficas:
    df = df[~df['user_location'].str.contains(frase, regex=False)]


df
# Out:
#                     user_name        user_location user_created  \
# 0               DeSota Wilson          atlanta, ga   2009-04-26
# 3                 Bitcoin-Bot         florida, usa   2019-12-23
# 4               DeSota Wilson          atlanta, ga   2009-04-26
# 7                CryptoSquawk            australia   2017-10-05
# 9               DeSota Wilson          atlanta, ga   2009-04-26
# ...                       ...                  ...          ...
# 2214127  Bingo Crypto Scanner                italy   2021-12-11
# 2214128      Niklas Feurstein              austria   2016-01-11
# 2214131        CryptoPredator  islamabad, pakistan   2022-12-31
# 2214132           CryptoClick         new york, ny   2009-07-16
# 2214135        Crypto Alerted                  usa   2020-04-10
#
#         user_followers user_friends user_favourites user_verified        date  \
# 0               8534.0         7605            4838         False  2021-02-10
# ...

# %%
unique_user_locations = df['user_location'].unique()

print(unique_user_locations)
# Out:
# 0                    atlanta, ga
# 1                   florida, usa
# 2                      australia
# 3                       pakistan
# 4                  las vegas, nv
#                   ...
# 85342         basel switzerland
# 85343               oslo, norge
# 85344    homer glen/lockport, il
# 85345         açailândia, brasil
# 85346     antalya, adana türkiye
# Name: user_location, Length: 85347, dtype: object

# %%
country_abr = [
    ("United States", "USA"),
    ("Canada", "CAN"),
    ("Australia", "AUS"),
    ("United Kingdom", "UK"),
    ("Germany", "DE"),
    ("France", "FR"),
    ("Brazil", "BR"),
    ("Turkey", "TR"),
    ("Switzerland", "CH"),
    ("Italy", "IT"),
    ("Spain", "ES"),
    ("Argentina", "ARG"),
    ("Mexico", "MEX"),
    ("Chile", "CHL"),
    ("Colombia", "COL"),
    ("Japan", "JP"),
    ("South Korea", "KR"),
    ("India", "IN"),
    ("China", "CN"),
    ("Russia", "RU"),
    ("Netherlands", "NL"),
    ("Belgium", "BE"),
    ("Austria", "AT"),
    ("Sweden", "SE"),
    ("Norway", "NO"),
    ("Denmark", "DK"),
    ("Finland", "FI"),
    ("Portugal", "PT"),
    ("Greece", "GR"),
    ("Poland", "PL"),
    ("Czech Republic", "CZ"),
    ("Slovakia", "SK"),
    ("Hungary", "HU"),
    ("Romania", "RO"),
    ("Bulgaria", "BG"),
    ("Croatia", "HR"),
    ("Serbia", "RS"),
    ("Slovenia", "SI"),
    ("Israel", "IL"),
    ("South Africa", "ZA"),
    ("Egypt", "EG"),
    ("Kenya", "KE"),
    ("Nigeria", "NG"),
    ("India", "IN"),
    ("Pakistan", "PK"),
    ("Bangladesh", "BD"),
    ("Indonesia", "ID"),
    ("Malaysia", "MY"),
    ("Singapore", "SG"),
    ("Philippines", "PH"),
    ("Vietnam", "VN"),
    ("Thailand", "TH"),
    ("Nepal", "NP"),
    ("Sri Lanka", "LK"),
    ("Mexico", "MX"),
    ("Costa Rica", "CR"),
    ("Panama", "PA"),
    ("Honduras", "HN"),
    ("Guatemala", "GT"),
    ("El Salvador", "SV"),
    ("Jamaica", "JM"),
    ("Trinidad and Tobago", "TT"),
    ("Barbados", "BB"),
    ("Saint Lucia", "LC"),
    ("Saint Vincent and the Grenadines", "VC"),
    ("Belize", "BZ"),
    ("Ecuador", "EC"),
    ("Peru", "PE"),
    ("Bolivia", "BO"),
    ("Paraguay", "PY"),
    ("Uruguay", "UY"),
    ("Venezuela", "VE"),
    ("Guinea", "GN"),
    ("Ivory Coast", "CI"),
    ("Mali", "ML"),
    ("Senegal", "SN"),
    ("Burkina Faso", "BF"),
    ("Liberia", "LR"),
    ("Ghana", "GH"),
    ("Togo", "TG"),
    ("Cameroon", "CM"),
    ("Chad", "TD"),
    ("Republic of the Congo", "CG"),
    ("Democratic Republic of the Congo", "CD"),
    ("Uganda", "UG"),
    ("Mozambique", "MZ"),
    ("Angola", "AO"),
    ("Zambia", "ZM"),
    ("Botswana", "BW"),
    ("Namibia", "NA"),
    ("Zimbabwe", "ZW"),
    ("Malawi", "MW"),
    ("Lesotho", "LS"),
    ("Mauritius", "MU"),
    ("Seychelles", "SC"),
    ("Gabon", "GA"),
    ("Equatorial Guinea", "GQ"),
    ("São Tomé and Príncipe", "STP"),
    ("Cape Verde", "CV"),
    ("Madagascar", "MG"),
    ("Mauritania", "MR"),
    ("Algeria", "DZ"),
    ("Tunisia", "TN"),
    ("Libya", "LY"),
    ("Morocco", "MA"),
    ("Western Sahara", "EH"),
    ("Jordan", "JO"),
    ("Lebanon", "LB"),
    ("Iraq", "IQ"),
    ("Syria", "SY"),
    ("Saudi Arabia", "SA"),
    ("Kuwait", "KW"),
    ("Bahrain", "BH"),
    ("Qatar", "QA"),
    ("United Arab Emirates", "AE"),
    ("Oman", "OM"),
    ("Yemen", "YE"),
    ("Afghanistan", "AF"),
    ("Turkmenistan", "TM"),
    ("Kazakhstan", "KZ"),
    ("Uzbekistan", "UZ"),
    ("Kyrgyzstan", "KG"),
    ("Tajikistan", "TJ"),
    ("Armenia", "AM"),
    ("Georgia", "GE"),
    ("Azerbaijan", "AZ"),
    ("Moldova", "MD"),
    ("Belarus", "BY"),
    ("Ukraine", "UA"),
    ("Montenegro", "ME"),
    ("North Macedonia", "MK"),
    ("Albania", "AL"),
    ("Kosovo", "XK"),
    ("Liechtenstein", "LI"),
    ("Monaco", "MC"),
    ("San Marino", "SM"),
    ("Andorra", "AD"),
    ("Vatican City", "VA"),
    ("Luxembourg", "LU"),
    ("Malta", "MT"),
    ("Iceland", "IS"),
    ("Bermuda", "BM"),
    ("Greenland", "GL"),
    ("Saint Kitts and Nevis", "KN"),
    ("Antigua and Barbuda", "AG"),
    ("Saint Barthélemy", "BL"),
    ("Saint Pierre and Miquelon", "PM"),
    ("French Guiana", "GF"),
    ("Guadeloupe", "GP"),
    ("Martinique", "MQ"),
    ("Reunion", "RE"),
    ("Mayotte", "YT"),
    ("New Caledonia", "NC"),
    ("French Polynesia", "PF"),
    ("Wallis and Futuna", "WF"),
    ("French Southern and Antarctic Lands", "TF"),
]

# %%
df = df.to_pandas()

# %%
def replace_country(location, country_abr):
    for coun, abrev in country_abr:
        if coun.lower() in location.lower() or abrev.lower() in location.lower():
            return coun
    return None 

df['user_location'] = df['user_location'].apply(lambda x: replace_country(x, country_abr))

df = df[df['user_location'].notna()]
df
# Out:
#                     user_name   user_location user_created user_followers  \
# 0               DeSota Wilson         Austria   2009-04-26         8534.0
# 3                 Bitcoin-Bot   United States   2019-12-23          131.0
# 4               DeSota Wilson         Austria   2009-04-26         8534.0
# 7                CryptoSquawk       Australia   2017-10-05         1281.0
# 9               DeSota Wilson         Austria   2009-04-26         8534.0
# ...                       ...             ...          ...            ...
# 2214125        Crypto Rosetta  United Kingdom   2022-07-11            224
# 2214127  Bingo Crypto Scanner           Italy   2021-12-11           2921
# 2214128      Niklas Feurstein       Australia   2016-01-11           7475
# 2214131        CryptoPredator        Pakistan   2022-12-31             17
# 2214135        Crypto Alerted   United States   2020-04-10           1117
#
#         user_friends user_favourites user_verified        date  \
# ...

# %%
df['hashtags'] = df['hashtags'].apply(lambda x: [hashtag.lower() for hashtag in x] if isinstance(x, list) else (x.lower() if isinstance(x, str) else x))
df['source'] = df['source'].apply(lambda x: [hashtag.lower() for hashtag in x] if isinstance(x, list) else (x.lower() if isinstance(x, str) else x))
df
# Out:
#                     user_name   user_location user_created user_followers  \
# 0               DeSota Wilson         Austria   2009-04-26         8534.0
# 3                 Bitcoin-Bot   United States   2019-12-23          131.0
# 4               DeSota Wilson         Austria   2009-04-26         8534.0
# 7                CryptoSquawk       Australia   2017-10-05         1281.0
# 9               DeSota Wilson         Austria   2009-04-26         8534.0
# ...                       ...             ...          ...            ...
# 2214125        Crypto Rosetta  United Kingdom   2022-07-11            224
# 2214127  Bingo Crypto Scanner           Italy   2021-12-11           2921
# 2214128      Niklas Feurstein       Australia   2016-01-11           7475
# 2214131        CryptoPredator        Pakistan   2022-12-31             17
# 2214135        Crypto Alerted   United States   2020-04-10           1117
#
#         user_friends user_favourites user_verified        date  \
# ...

# %%
value_counts = df['source'].value_counts()
threshold = value_counts.sum()/150
threshold
# Out:
# 12312.946666666667

# %%
sources_to_remove = value_counts[value_counts <= threshold].index
df2 = df[~df['source'].isin(sources_to_remove)]
print(df2['source'].value_counts())
print(len(df2['source'].value_counts()))
df2
# Out:
# source
# twitter web app             489486
# twitter for android         455148
# twitter for iphone          419154
# ifttt                        34953
# contentstudio.io             27973
# microsoft power platform     24392
# tweetdeck                    18677
# dlvr.it                      18412
# bitcoinagile                 14088
# twitter for ipad             13698
# iambitcoinbot                13688
# Name: count, dtype: int64
# 11
#                     user_name   user_location user_created user_followers  \
# 0               DeSota Wilson         Austria   2009-04-26         8534.0
# 4               DeSota Wilson         Austria   2009-04-26         8534.0
# 9               DeSota Wilson         Austria   2009-04-26         8534.0
# 11                Humayun MHA        Pakistan   2016-08-18         1392.0
# 13            Stefan Gyarmati     Switzerland   2009-06-01           62.0
# ...                       ...             ...          ...            ...
# ...

# %%
type(df)
min(df['date'])
# Out:
# '2021-02-05'

# %%
#df.to_csv("bitcoin_tweet_procress.csv", index=False)
